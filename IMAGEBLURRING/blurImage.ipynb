# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import os

source_dir = "/content/drive/MyDrive/asgmt1/CAPTURE/"
out_dir = "/content/drive/MyDrive/asgmt1/blurImage/"
filenames = os.listdir(source_dir)

for filename in filenames:
  print(source_dir + filename)
  image = cv2.imread(source_dir + filename, 1)
  grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

  faces = face_cascade.detectMultiScale(grayImage,1.1,4)
  print(f"{len(faces)} faces detected in the image.")

  for x,y,w,h in faces:
    face_roi = image[y:y + h, x:x+w]
    blurImage = cv2.GaussianBlur(face_roi,(15,15),10)
    image[y:y+h, x:x+w] = blurImage

  cv2_imshow(image)
  cv2.imwrite(out_dir + "blur_" + filename, image)
# Out:
# /content/drive/MyDrive/asgmt1/CAPTURE/photo0.jpg
# 1 faces detected in the image.
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F9EEB6E6C90>
# /content/drive/MyDrive/asgmt1/CAPTURE/photo1.jpg
# 1 faces detected in the image.
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F9EEB47C8D0>
# /content/drive/MyDrive/asgmt1/CAPTURE/photo2.jpg
# 1 faces detected in the image.
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F9EEB46F810>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
